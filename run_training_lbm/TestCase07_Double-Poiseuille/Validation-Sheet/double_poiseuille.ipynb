# %% [markdown]
# # Double Poiseuille pour plusieurs ratios de viscosité

# %% [markdown]
# ## Cadre

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
#  ## Solution analytique

# %% [markdown]
# $u_y(x) =
# \begin{cases}
# \frac{Gh^2}{2 \eta_A} \left[ - \left( \frac{x}{h} \right)^2 - \frac{x}{h} \left( \frac{\eta_A - \eta_B}{\eta_A + \eta_B} \right) + \frac{2 \eta_A}{\eta_A + \eta_B} \right] & \text{si } 0 \leq x \leq h \\
# \frac{Gh^2}{2 \eta_B} \left[ - \left( \frac{x}{h} \right)^2 - \frac{x}{h} \left( \frac{\eta_A - \eta_B}{\eta_A + \eta_B} \right) + \frac{2 \eta_B}{\eta_A + \eta_B} \right] & \text{si } -h \leq x \leq 0
# \end{cases}$
#
# avec $G = \frac{u_c}{h^2} ( \eta_A + \eta_B)$ et $u_c = 5 \times 10^{-5}$.
#
# Terme force: $F_y = \rho G$ avec $\rho = 1$.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# $$ \text{ Profil de la solution analytique d'un écoulement de Double Poiseuille pour deux fluides} A \text{ et } B \text{ d'un ration de densité } \eta_A / \eta_B = 10 $$

# %% [markdown]
# ### Données d'entrée

# %% [markdown]
# Dans le fichier .ini, utiliser les valeurs suivantes:

# %%
u_c = 5e-5
h = 1.28
eta_B = 0.00166666666
print("xmin = ", -h)
print("xmax = ", h)
print("nu0  = ", eta_B)
# Out:
# xmin =  -1.28
# xmax =  1.28
# nu0  =  0.00166666666

# %% [markdown]
# ## Simulations

# %% [markdown]
# ## $\eta_A / \eta_B = 10$

# %% [markdown]
# ### Données d'entrée

# %%
eta_A = 0.0166666666
G= u_c * (eta_A + eta_B) / h**2
print("nu1 = ", eta_A)
print("gy  = ", G)
# Out:
# nu1 =  0.0166666666
# gy  =  5.59488930053711e-07

# %% [markdown]
# ### Résultats

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv


x_list=np.array([])
u_y = np.array([])
with open('profil_doublepoiseuille_10.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        if row[0]!= 'laplaphi':
            x_list = np.append(x_list, float(row[21]))
            u_y = np.append(u_y, float(row[8]))

u_th = np.zeros(len(x_list))
for i,x in enumerate(x_list):
    if x >=0:
        u_th[i] = G * h**2 / (2*eta_A) * (-(x/h)**2 - x/h * (eta_A - eta_B)/(eta_A + eta_B) + 2 * eta_A / (eta_A + eta_B))
    else: 
        u_th[i] = G * h**2 / (2*eta_B) * (-(x/h)**2 - x/h * (eta_A - eta_B)/(eta_A + eta_B) + 2 * eta_B / (eta_A + eta_B))

x_list = x_list /h
        
fig,ax = plt.subplots()
fig.set_size_inches(12,8, forward = True)
l1, = ax.plot(u_th,x_list, color = 'r')
l2, = ax.plot(u_y,x_list, linestyle= 'None',marker = 'o', markerfacecolor = 'blue', markeredgecolor='blue', markevery= 4)
ax.legend( (l1,l2), ('analytique','simulation'), loc= 'upper right', shadow = True)
ax.set_title("Profil d'un écoulement de double Poiseuille pour $ \eta_A / \eta_B = 10$" )
ax.set_xlabel('$u_y(x)$')
ax.set_ylabel('$x$')
plt.show()

# %% [markdown]
# ## $ \eta_A / \eta_B = 50$

# %% [markdown]
# ### Données d'entrée

# %%
eta_A = 0.083333333
G= u_c * (eta_A + eta_B) / h**2
print("nu1 = ", eta_A)
print("gy  = ", G)
# Out:
# nu1 =  0.083333333
# gy  =  2.593994130249023e-06

# %% [markdown]
# ### Résultats

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv


x_list=np.array([])
u_y = np.array([])
with open('profil_doublepoiseuille_50.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        if row[0]!= 'laplaphi':
            x_list = np.append(x_list, float(row[21]))
            u_y = np.append(u_y, float(row[8]))

u_th = np.zeros(len(x_list))
for i,x in enumerate(x_list):
    if x >=0:
        u_th[i] = G * h**2 / (2*eta_A) * (-(x/h)**2 - x/h * (eta_A - eta_B)/(eta_A + eta_B) + 2 * eta_A / (eta_A + eta_B))
    else: 
        u_th[i] = G * h**2 / (2*eta_B) * (-(x/h)**2 - x/h * (eta_A - eta_B)/(eta_A + eta_B) + 2 * eta_B / (eta_A + eta_B))

x_list = x_list /h
        
fig,ax = plt.subplots()
fig.set_size_inches(12,8, forward = True)
l1, = ax.plot(u_th,x_list, color = 'r')
l2, = ax.plot(u_y,x_list, linestyle= 'None',marker = 'o', markerfacecolor = 'blue', markeredgecolor='blue', markevery= 4)

ax.legend( (l1,l2), ('analytique','simulation'), loc= 'upper right', shadow = True)
ax.set_title("Profil d'un écoulement de double Poiseuille pour $ \eta_A / \eta_B = 50$" )
ax.set_xlabel('$u_y(x)$')
ax.set_ylabel('$x$')
plt.show()

# %% [markdown]
# ## $ \eta_A / \eta_B = 100$

# %% [markdown]
# ### Données d'entrée

# %%
eta_A = 0.166666666
G= u_c * (eta_A + eta_B) / h**2
print("nu1 = ", eta_A)
print("gy  = ", G)
# Out:
# nu1 =  0.166666666
# gy  =  5.137125630493164e-06

# %% [markdown]
# ### Résultats

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv


x_list=np.array([])
u_y = np.array([])
with open('profil_doublepoiseuille_100.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        if row[0]!= 'laplaphi':
            x_list = np.append(x_list, float(row[21]))
            u_y = np.append(u_y, float(row[8]))
                    
u_th = np.zeros(len(x_list))
for i,x in enumerate(x_list):
    if x >=0:
        u_th[i] = G * h**2 / (2*eta_A) * (-(x/h)**2 - x/h * (eta_A - eta_B)/(eta_A + eta_B) + 2 * eta_A / (eta_A + eta_B))
    else: 
        u_th[i] = G * h**2 / (2*eta_B) * (-(x/h)**2 - x/h * (eta_A - eta_B)/(eta_A + eta_B) + 2 * eta_B / (eta_A + eta_B))

x_list = x_list /h

fig,ax = plt.subplots()
fig.set_size_inches(12,8, forward = True)
l1, = ax.plot(u_th,x_list, color = 'r')
l2, = ax.plot(u_y,x_list, linestyle= 'None',marker = 'o', markerfacecolor = 'blue', markeredgecolor='blue', markevery= 4)

ax.legend( (l1,l2), ('analytique','simulation'), loc= 'upper right', shadow = True)
ax.set_title("Profil d'un écoulement de double Poiseuille pour $ \eta_A / \eta_B = 100$" )
ax.set_ylabel('$x$')
ax.set_xlabel('$u_y(x)$')
plt.show()

# %% [markdown]
# ## .ini

# %% [raw]
# [run]
# lbm_name=D2Q9
# tEnd=300000.0
# nStepmax=300001
# nOutput=10000
# nlog=5000000
# dt=1e-2
#
# [mesh]
# nx=256
# ny=64
#
# xmin=-1.28
# xmax=1.28
#
# ymin=0.00
# ymax=0.64
#
# #choices are "periodic"/"zero_flux"/"antibounceback"
# boundary_type_xmin=zero_flux
# boundary_type_xmax=zero_flux
# boundary_type_ymin=periodic
# boundary_type_ymax=periodic
#
# [lbm]
# problem=NSAC_Comp
# model=base
# e2=3.0
#
# [equation1]
# boundary_type_xmin=zero_flux
# boundary_type_xmax=zero_flux
# boundary_type_ymin=periodic
# boundary_type_ymax=periodic
# [equation2]
# boundary_type_xmin=zero_flux
# boundary_type_xmax=zero_flux
# boundary_type_ymin=periodic
# boundary_type_ymax=periodic
#
# [phase_field_boundary]
# #values used for antibounceback
# boundary_value_xmin=0.0
# boundary_value_xmax=0.0
# boundary_value_ymin=0.0
# boundary_value_ymax=0.0
#
#
# [vx_boundary]
# #values used for bounceback
# boundary_value_xmin=0.0
# boundary_value_xmax=0.0
# boundary_value_ymin=0.0
# boundary_value_ymax=0.0
#
# [vy_boundary]
# boundary_value_xmin=0.0
# boundary_value_xmax=0.0
# boundary_value_ymin=0.0
# boundary_value_ymax=0.0
#
# [params]
# W = 0.02
# Mphi = 0.0016666666666
# lambda = 0.0
# counter_term=0.0
# gamma=1.0
# rho0=1
# rho1=1
# nu0=0.00166666666666
# nu1=0.166666666666
# hstar=0.0
# PF_advec=0.0
# gx=0
# gy=5.137125630493164e-06
# gz=0
# rho0_ini=1
# rho1_ini=1
# rho0_eq=1
# rho1_eq=1
#
# [params_composition]
# c0_co=0.3
# c1_co=0.5
# mu_eq=0.0
# c0_inf=0.5
# c1_inf=0.3
#
#
# [init]
# init_type=vertical
# x0=0.00
# sign=1.0
# initVX=0.0
# initVY=0.0
#
#
# [output]
# write_variables=vx,vy,phi
# outputPrefix=double_poiseuille_100
# outputVtkAscii=yes
# vtk_enabled=yes
# outputDir=./
# hdf5_enabled=no
# #c0co0.3c1co0.5c0inf0.5c1inf0.3mueq0.0rho0ini3rho1ini1rho0inf1rho1inf3
